# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills/blob/main/Skills%20Programming%20Lesson%204_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Skills Lesson 4

# %%
# Task 1
import array                                                                                                # import the packages
try:                                                                                                        # safety net - prepare in case someone put letter or technical sign $
  # create the array with the input of user (transform every entry into an integer)
  my_array = array.array("i", [int(x) for x in input("Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma").split(",")])
  print(f"The array is: {my_array}")                                                                        # print the result in order to check the array and see which element one want to delete
  value = int(input("Which element number do you want to delete? Please indicate its position in the order: "))                                       # input from user to delete an element
  if value < 1 or value > len(my_array):                                                                    # just add the conditional to make sure the element is in the array (note that we ask for the coordinate)
      print(f"Error: element number {value} does not exist in the array (valid range: 1-{len(my_array)})")  # return error message
  else:                                                                                                     # the right value can be delete as it is valid (it has a valid coordinate)
      del my_array[value - 1]                                                                               # delete the value depending on its coordinate (hence the -1 as the indexation start at -1)
      print(f"New array: {my_array} after the deletion of {value}")                                         # Result message
except ValueError:                                                                                          # second part of the safety net -prepare in case someone put letter or technical sign $
  print("Please give a valid input.")                                                                       # error message
# Out:
# Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma1,2,3
# The array is: array('i', [1, 2, 3])
# Which element number do you want to delete? Please indicate its position in the order: 2
# New array: array('i', [1, 3]) after the deletion of 2

# %%
# Task 2
# the array only accept number to add them to the list

import array                                                                    # import the packages
try:                                                                            # safety net - prepare in case someone put letter or technical sign $
  # create the array with the input of user
  my_array = array.array("i", [int(x) for x in input("Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma").split(",")])
  print(f"The array is: {my_array}")                                            # just check the array in order to see which element one want to delete
  value = int(input("Which element number do you want to add?: "))              # new element that the user want to add (input)
  if isinstance(value, int):                                                    # create the conditional part just to make sure the input is valid (only accept integer)
    my_array.append(value)                                                      # the true value that we just added
  else:
    print("Please give a valid input.")                                         # invalid input - if want to add a letter
  print(f"New array: {my_array} after the addition of {value}")                 # print the result after adding the new element
  print(f"The lenght of the array is : {len(my_array)}")
except ValueError:                                                              # prepare in case someone put letter or technical sign $
  print("Please give a valid input.")                                           # error message
# Out:
# Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma12,4,5,6
# The array is: array('i', [12, 4, 5, 6])
# Which element number do you want to add?: 7
# New array: array('i', [12, 4, 5, 6, 7]) after the addition of 7
# The lenght of the array is : 5

# %%
# Task 3
l_numbers = []                              # create the basic list(number, string, names (all empty))
l_strings = []
l_names = []
l_numbers.append(1)                         # add the various component to the list using append, extend
l_numbers.extend([2,3])
l_strings.extend(["Hello","World"])         # note that extend can take different input and not only one
l_names.append("John")                      # note that append along take one element
l_names.extend(["Eric","Jessica"])
third_name = l_names[2]                     # create a list with the thrid component of the name
print(l_numbers)                            # print the result
print(l_strings)
print(l_names)
print(third_name)
# Out:
# [1, 2, 3]
# ['Hello', 'World']
# ['John', 'Eric', 'Jessica']
# Jessica

# %%
# task 3 more complex

l_numbers = []                                                   # create the three empty list
l_names = []
l_strings = []
# create a system that keeps asking the user what it want to add to the list
while True:                                                      # need an infinite list in order to keep asking to the user for new input
    choice = input("Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): ")        # here it is the input from the user (for any type of letter)
    if choice.upper() == "QUIT":                                 # add the quite function in order to make sure the loops stop
        break                                                    # stop the loop

    item = [item.strip() for item in choice.split(",")]          # separate the input from the user into different part
    for x in item:                                               # need to apply the for loop to all the components given by the user
      try:                                                       # use the safety net as a conditional (come from the Lecture Intro-To-Programming)
        number = int(x)                                          # transform the input as an integer (if the function works then it means that we can sort it as a number)
        l_numbers.append(number)                                 # add the number
        print(f"Sorted into numbers")
      except ValueError:                                         # if the program fails it means that it cannot be transform into an integer then we know that it is a letter (character) so it needs to be put in the other lists
        if x.isalpha() and x[0].isupper():                       # there is no easy way to know if it is a name or not but theoretically, the name start with an upper letter so we can check if it is a name or not
            l_names.append(x)                                    # if start with an upper letter then consider as a name so we add it to the name list
            print(f"Sorted into names")
        else:                                                    # if it does not start with an upper letter then we put it to the normal string list
            l_strings.append(x)                                  # add it to the list
            print(f"Sorted into strings")

# print the final result once the loop is over
print(f"\nNumbers: {l_numbers}")
print(f"Names: {l_names}")
print(f"Strings: {l_strings}")
# Out:
# Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): abc
# Sorted into strings
# Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): abc,def
# Sorted into strings
# Sorted into strings
# Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): 1,2,3
# Sorted into numbers
# Sorted into numbers
# Sorted into numbers
# Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): William Wuillemin,WilliamABC, manger,111
# Sorted into strings
# Sorted into names
# Sorted into strings
# Sorted into numbers
# Enter an input (it can have various input but you will need to separate it by a comma ) or QUIT to stop): quit
#
# Numbers: [1, 2, 3, 111]
# Names: ['WilliamABC']
# Strings: ['abc', 'abc', 'def', 'William Wuillemin', 'manger']
