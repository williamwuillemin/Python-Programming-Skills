# %% [markdown]
# <a href="https://colab.research.google.com/github/williamwuillemin/Python-Programming-Skills/blob/main/Skills%20Programming%20Lesson%204_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Skills Lesson 4

# %%
# Task 1
import array
# import the packages
try: # prepare in case someone put letter or technical sign $
  my_array = array.array("i", [int(x) for x in input("Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma").split(",")])
  # create the array with the input of user (transform every entry into an integer)
  print(f"The array is: {my_array}")
  # just check the array in order to see which element one want to delete
  value = int(input("Which element number do you want to delete?: "))
  # just add the conditional to make sure the element is in the array
  if value < 1 or value > len(my_array):
      print(f"Error: element number {value} does not exist in the array (valid range: 1-{len(my_array)})")
  else: # the right value can be delete as it is valid
      del my_array[value - 1]
      print(f"New array: {my_array} after the deletion of {value}")
except ValueError: # prepare in case someone put letter or technical sign $
  print("Please give a valid input.")
# Out:
# Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma1,2,a
# Please give a valid input.

# %%
# Task 2
# Task 1
import array
# import the packages
try: # prepare in case someone put letter or technical sign $
  my_array = array.array("i", [int(x) for x in input("Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma").split(",")])
  # create the array with the input of user
  print(f"The array is: {my_array}")
  # just check the array in order to see which element one want to delete
  value = int(input("Which element number do you want to add?: "))
  # create the conditional part just to make sure the input is valid
  if isinstance(value, int):
    my_array.append(value)
  else:       # the true value that we just added
    print("Please give a valid input. No  .")
  print(f"New array: {my_array} after the addition of {value}")
except ValueError: # prepare in case someone put letter or technical sign $
  print("Please give a valid input.")
# Out:
# Enter a list of integer to put in the initial array. Note that it needs to be separated by a comma1,2,3,4,5,6
# The array is: array('i', [1, 2, 3, 4, 5, 6])
# Which element number do you want to add?: a
# Please give a valid input.

# %%
# Task 3
l_numbers = []
l_strings = []
l_names = []
l_numbers.append(1)
l_numbers.extend([2,3])
l_strings.extend(["Hello","World"])
l_names.append("John")
l_names.extend(["Eric","Jessica"])
third_name = l_names[2]
print(l_numbers)
print(l_strings)
print(l_names)
print(third_name)
# Out:
# [1, 2, 3]
# ['Hello', 'World']
# ['John', 'Eric', 'Jessica']
# Jessica
